# %%
import pandas as pd

# %%
info = pd.read_csv("plant_health_data.csv")

# %%
info.head(5)
# Out:
#                     Timestamp  Plant_ID  Soil_Moisture  Ambient_Temperature  \
# 0  2024-10-03 10:54:53.407995         1      27.521109            22.240245
# 1  2024-10-03 16:54:53.407995         1      14.835566            21.706763
# 2  2024-10-03 22:54:53.407995         1      17.086362            21.180946
# 3  2024-10-04 04:54:53.407995         1      15.336156            22.593302
# 4  2024-10-04 10:54:53.407995         1      39.822216            28.929001
#
#    Soil_Temperature   Humidity  Light_Intensity   Soil_pH  Nitrogen_Level  \
# 0         21.900435  55.291904       556.172805  5.581955       10.003650
# 1         18.680892  63.949181       596.136721  7.135705       30.712562
# 2         15.392939  67.837956       591.124627  5.656852       29.337002
# 3         22.778394  58.190811       241.412476  5.584523       16.966621
# 4         18.100937  63.772036       444.493830  5.919707       10.944961
#
#    Phosphorus_Level  Potassium_Level  Chlorophyll_Content  \
# ...

# %%
info.tail(5)
# Out:
#                        Timestamp  Plant_ID  Soil_Moisture  \
# 1195  2024-11-01 04:54:53.493508        10      29.665780
# 1196  2024-11-01 10:54:53.493508        10      15.490782
# 1197  2024-11-01 16:54:53.493508        10      23.495723
# 1198  2024-11-01 22:54:53.493508        10      30.971675
# 1199  2024-11-02 04:54:53.493508        10      24.406357
#
#       Ambient_Temperature  Soil_Temperature   Humidity  Light_Intensity  \
# 1195            27.605285         15.381699  54.668196       650.536854
# 1196            22.108112         15.221033  61.243143       768.760787
# 1197            21.680240         15.499764  40.693671       293.643366
# 1198            23.019488         21.934918  41.387107       492.952014
# 1199            25.724605         23.358573  47.505394       304.201566
#
#        Soil_pH  Nitrogen_Level  Phosphorus_Level  Potassium_Level  \
# 1195  5.715289       29.993107         14.914470        21.560747
# ...

# %%
info.describe()
# Out:
#           Plant_ID  Soil_Moisture  Ambient_Temperature  Soil_Temperature  \
# count  1200.000000    1200.000000          1200.000000       1200.000000
# mean      5.500000      25.106918            23.999130         19.957794
# std       2.873479       8.677725             3.441561          2.932073
# min       1.000000      10.000724            18.001993         15.003710
# 25%       3.000000      17.131893            21.101766         17.353027
# 50%       5.500000      25.168333            23.889044         19.911473
# 75%       8.000000      32.370231            27.042634         22.596851
# max      10.000000      39.993164            29.990886         24.995929
#
#           Humidity  Light_Intensity      Soil_pH  Nitrogen_Level  \
# count  1200.000000      1200.000000  1200.000000     1200.000000
# mean     54.853165       612.637265     6.524102       30.106751
# std       8.784916       228.318853     0.581755       11.514396
# ...

# %%
info.shape
# Out:
# (1200, 14)

# %%
info["Plant_ID"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 1195    10
# 1196    10
# 1197    10
# 1198    10
# 1199    10
# Name: Plant_ID, Length: 1200, dtype: int64

# %%
info[["Plant_ID","Soil_Temperature"]]
# Out:
#       Plant_ID  Soil_Temperature
# 0            1         21.900435
# 1            1         18.680892
# 2            1         15.392939
# 3            1         22.778394
# 4            1         18.100937
# ...        ...               ...
# 1195        10         15.381699
# 1196        10         15.221033
# 1197        10         15.499764
# 1198        10         21.934918
# 1199        10         23.358573
#
# [1200 rows x 2 columns]

# %%
info["Soil_Temperature"].unique()
# Out:
# array([21.90043536, 18.68089194, 15.39293913, ..., 15.49976449,
#        21.9349176 , 23.3585726 ])

# %%
info[info["Plant_ID"]==1]
# Out:
#                       Timestamp  Plant_ID  Soil_Moisture  Ambient_Temperature  \
# 0    2024-10-03 10:54:53.407995         1      27.521109            22.240245
# 1    2024-10-03 16:54:53.407995         1      14.835566            21.706763
# 2    2024-10-03 22:54:53.407995         1      17.086362            21.180946
# 3    2024-10-04 04:54:53.407995         1      15.336156            22.593302
# 4    2024-10-04 10:54:53.407995         1      39.822216            28.929001
# ..                          ...       ...            ...                  ...
# 115  2024-11-01 04:54:53.407995         1      33.461392            27.930262
# 116  2024-11-01 10:54:53.407995         1      38.657826            23.449221
# 117  2024-11-01 16:54:53.407995         1      19.156338            22.810290
# 118  2024-11-01 22:54:53.407995         1      24.678082            19.155544
# 119  2024-11-02 04:54:53.407995         1      36.657558            22.802209
#
# ...

# %%
info [(info["Plant_Health_Status"]=="Healthy")&(info["Plant_ID"]==1)]
# Out:
#                       Timestamp  Plant_ID  Soil_Moisture  Ambient_Temperature  \
# 11   2024-10-06 04:54:53.407995         1      31.606611            23.994648
# 20   2024-10-08 10:54:53.407995         1      37.396984            28.416182
# 21   2024-10-08 16:54:53.407995         1      37.745170            20.530868
# 22   2024-10-08 22:54:53.407995         1      32.701840            29.192803
# 23   2024-10-09 04:54:53.407995         1      39.446354            24.289709
# 24   2024-10-09 10:54:53.407995         1      39.567367            25.550267
# 27   2024-10-10 04:54:53.407995         1      33.156481            19.029637
# 31   2024-10-11 04:54:53.407995         1      39.838764            21.653532
# 32   2024-10-11 10:54:53.407995         1      37.702538            18.281271
# 34   2024-10-11 22:54:53.407995         1      31.283431            22.240912
# 41   2024-10-13 16:54:53.407995         1      32.383673            29.990886
# ...

# %%
info.groupby("Plant_Health_Status")["Plant_ID"].sum()
# Out:
# Plant_Health_Status
# Healthy            1610
# High Stress        2803
# Moderate Stress    2187
# Name: Plant_ID, dtype: int64

# %%
info.groupby("Plant_Health_Status")["Plant_ID"].min()
# Out:
# Plant_Health_Status
# Healthy            1
# High Stress        1
# Moderate Stress    1
# Name: Plant_ID, dtype: int64

# %%
info.groupby("Plant_Health_Status")["Plant_ID"].max()
# Out:
# Plant_Health_Status
# Healthy            10
# High Stress        10
# Moderate Stress    10
# Name: Plant_ID, dtype: int64

# %%
info.loc[1100]
# Out:
# Timestamp                 2024-10-08 10:54:53.493508
# Plant_ID                                          10
# Soil_Moisture                              22.015879
# Ambient_Temperature                        29.606688
# Soil_Temperature                           21.421047
# Humidity                                    63.83221
# Light_Intensity                           392.309867
# Soil_pH                                     6.474126
# Nitrogen_Level                             38.727478
# Phosphorus_Level                           19.848685
# Potassium_Level                            14.825154
# Chlorophyll_Content                        48.896981
# Electrochemical_Signal                       1.26613
# Plant_Health_Status                  Moderate Stress
# Name: 1100, dtype: object

# %%
info.iloc[5,13]
# Out:
# 'High Stress'
